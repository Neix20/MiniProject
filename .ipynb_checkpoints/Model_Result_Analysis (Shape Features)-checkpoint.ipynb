# %% [markdown]
# ## Load Libraries

# %%
import os
import cv2
import math
import pickle
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import skimage.measure
import matplotlib.pyplot as plt

from glob import glob
from sklearn import svm
from sklearn.multiclass import OneVsRestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from skimage.feature import greycomatrix, greycoprops
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, roc_curve, accuracy_score
# %matplotlib inline

# %% [markdown]
# ## Remove White Background (Thresholding)

# %%
def remove_background(img, threshold):
    """
    This method removes background from your image
    
    :param img: cv2 image
    :type img: np.array
    :param threshold: threshold value for cv2.threshold
    :type threshold: float
    :return: RGBA image
    :rtype: np.ndarray
    """
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, threshed = cv2.threshold(gray, threshold, 255, cv2.THRESH_BINARY_INV)
    
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (11, 11))
    morphed = cv2.morphologyEx(threshed, cv2.MORPH_CLOSE, kernel)
    
    cnts = cv2.findContours(morphed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[0]
    cnt = sorted(cnts, key=cv2.contourArea)[-1]

    mask = cv2.drawContours(threshed, cnt, 0, (0, 255, 0), 0)
    masked_data = cv2.bitwise_and(img, img, mask=mask)

    x, y, w, h = cv2.boundingRect(cnt)
    dst = masked_data[y: y + h, x: x + w]

    dst_gray = cv2.cvtColor(dst, cv2.COLOR_BGR2GRAY)
    _, alpha = cv2.threshold(dst_gray, 0, 255, cv2.THRESH_BINARY)
    b, g, r = cv2.split(dst)

    rgba = [r, g, b, alpha]
    dst = cv2.merge(rgba, 4)
    
    dst = cv2.cvtColor(dst, cv2.COLOR_BGRA2RGB)

    return dst

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("Image_Dataset_Color_Texture_Shape_Features.csv")

# %% [markdown]
# ## Convert Image Path to OpenCV Image

# %%
def convert_img_path_to_cv_img(img_path, threshold = 225, ht = 100, wt = 100):
    cv_img = cv2.imread(img_path)
    
    # Resize Image
    cv_img = cv2.resize(cv_img, (wt,ht),interpolation = cv2.INTER_AREA)
    
    # Remove Background
    cv_img = remove_background(cv_img, threshold)
    
    # Convert Image from RGB to BGR
    cv_img = cv2.cvtColor(cv_img, cv2.COLOR_BGR2RGB)
    
    return cv_img

# %% [markdown]
# ## Seperate the target and independant variables

# %%
df_X = df.iloc[:, -10:-1]
df_Y = df.iloc[:, -1]

# %% [markdown]
# ## Show 6 Fruit Image

# %%
default_dataset_folder_path = "Dataset"

# %%
img_path_arr = [f"{default_dataset_folder_path}\\{fruit_str}\\0_100.jpg" for fruit_str in sorted(df_Y.unique())]
img_arr = [convert_img_path_to_cv_img(img_path) for img_path in img_path_arr]

# %%
fig, axs = plt.subplots(2, 3, figsize=(5,5))
    
n = 0
for i in range(0, 2):
    for j in range(0, 3):
        axs[i, j].imshow(img_arr[n], interpolation = 'nearest')
        axs[i, j].axis('off')
        n += 1

# %% [markdown]
# ## Show Front View, Side View, Top Down View of Fruit Image

# %%
img_path_arr = []

# Apple
img_path_arr += [f"{default_dataset_folder_path}\\Apple\\{tmp_str}.jpg" for tmp_str in ["0_100", "r_100_100", "r_196_100"]]

# Lemon
img_path_arr += [f"{default_dataset_folder_path}\\Lemon\\{tmp_str}.jpg" for tmp_str in ["0_100", "r_0_100", "r_100_100"]]

# Lychee
img_path_arr += [f"{default_dataset_folder_path}\\Lychee\\{tmp_str}.jpg" for tmp_str in ["0_100", "r_0_100", "r_100_100"]]

# %%
img_arr = [convert_img_path_to_cv_img(img_path) for img_path in img_path_arr]

# %%
fig, axs = plt.subplots(3, 3, figsize=(5,5))
    
n = 0
for i in range(0, 3):
    for j in range(0, 3):
        axs[i, j].imshow(img_arr[n], interpolation = 'nearest')
        axs[i, j].axis('off')
        n += 1

# %% [markdown]
# ## Convert Image to Canny

# %% [markdown]
# ### Convert OpenCV Image to Image Canny

# %%
def convert_img_to_canny(img_path, threshold = 225, ht = 100, wt = 100):
    img = cv2.imread(img_path)
    
    # Resize Image
    img = cv2.resize(img, (wt,ht),interpolation = cv2.INTER_AREA)
    
    # Remove Background
    img = remove_background(img, threshold = 225)
    
    # Convert Image to GrayScale Image
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Apply Gaussian Blur to Image
    img_blur = cv2.GaussianBlur(img_gray, (7,7), 1)
    
    # Canny Detection
    img_canny = cv2.Canny(img_blur, 50, 150)
    return img_canny

# %%
img_arr = [convert_img_to_canny(img_path) for img_path in img_path_arr]

# %%
fig, axs = plt.subplots(3, 3, figsize=(5,5))
    
n = 0
for i in range(0, 3):
    for j in range(0, 3):
        axs[i, j].imshow(img_arr[n], interpolation = 'nearest')
        axs[i, j].axis('off')
        n += 1

# %% [markdown]
# ## Generate Hu Moments

# %%
def gen_hu_moment(img_canny):
    kernel = np.ones((7, 7), dtype = np.uint8)
    img_dilate = cv2.dilate(img_canny, kernel, iterations = 1)

    contours, hier = cv2.findContours(img_dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    mu, huMoments = [], []
    for cnt in contours:
        mu = cv2.moments(cnt)
        huMoments = cv2.HuMoments(mu)
    
    for i in range(0,7):
        huMoments[i] = -1* math.copysign(1.0, huMoments[i]) * math.log10(abs(huMoments[i]) if abs(huMoments[i]) > 0 else 1)
    
    return {f"Hu Moment {(i + 1)}":huMoment[0] for (i, huMoment) in enumerate(huMoments)}

# %%
feature_arr = [f"Hu Moment {(i + 1)}" for i in range(7)]
final_df = pd.DataFrame(columns = feature_arr)
final_df
# Out:
# Empty DataFrame
# Columns: [Hu Moment 1, Hu Moment 2, Hu Moment 3, Hu Moment 4, Hu Moment 5, Hu Moment 6, Hu Moment 7]
# Index: []

# %% [markdown]
# ## Image Path Array

# %%
img_path_arr = []

# Apple
apple_arr = [f"{default_dataset_folder_path}\\Apple\\{tmp_str}.jpg" for tmp_str in ["0_100", "r_100_100", "r_196_100"]]

# Lemon
lemon_arr = [f"{default_dataset_folder_path}\\Lemon\\{tmp_str}.jpg" for tmp_str in ["0_100", "r_0_100", "r_100_100"]]

# Lychee
lychee_arr = [f"{default_dataset_folder_path}\\Lychee\\{tmp_str}.jpg" for tmp_str in ["0_100", "r_0_100", "r_100_100"]]

for (apple, lemon, lychee) in zip(apple_arr, lemon_arr, lychee_arr):
    img_path_arr += [apple, lemon, lychee]

# %% [markdown]
# ## Front View

# %%
feature_arr = [f"Hu Moment {(i + 1)}" for i in range(7)]
final_df = pd.DataFrame(columns = feature_arr)

fig, axs = plt.subplots(2, 3, figsize=(5,5))

for (ind, img_path) in enumerate(img_path_arr[:3]):
    axs[0, ind].imshow(convert_img_path_to_cv_img(img_path), interpolation = 'nearest')
    axs[0, ind].axis('off')
    
    axs[1, ind].imshow(convert_img_to_canny(img_path), interpolation = 'nearest')
    axs[1, ind].axis('off')
    final_df = final_df.append(gen_hu_moment(convert_img_to_canny(img_path)), ignore_index = True)
plt.show()

final_df = final_df.T
final_df = final_df.rename(columns = {ind:val.capitalize() for (ind, val) in enumerate(["apple", "lemon", "lychee"])})
display(final_df)
# Out:
#                  Apple     Lemon     Lychee
# Hu Moment 1   0.794710 -0.027950   0.788678
# Hu Moment 2   4.335847  0.689861   3.205142
# Hu Moment 3   4.648559  0.519662   4.322566
# Hu Moment 4   7.668456  1.410814   7.017833
# Hu Moment 5 -13.897716 -2.403151 -12.740638
# Hu Moment 6 -10.064184 -1.871531  -8.696144
# Hu Moment 7 -14.104888 -2.841355  13.021665

# %% [markdown]
# ## Side View

# %%
feature_arr = [f"Hu Moment {(i + 1)}" for i in range(7)]
final_df = pd.DataFrame(columns = feature_arr)

fig, axs = plt.subplots(2, 3, figsize=(5,5))

for (ind, img_path) in enumerate(img_path_arr[3:6]):
    axs[0, ind].imshow(convert_img_path_to_cv_img(img_path), interpolation = 'nearest')
    axs[0, ind].axis('off')
    
    axs[1, ind].imshow(convert_img_to_canny(img_path), interpolation = 'nearest')
    axs[1, ind].axis('off')
    final_df = final_df.append(gen_hu_moment(convert_img_to_canny(img_path)), ignore_index = True)
plt.show()

final_df = final_df.T
final_df = final_df.rename(columns = {ind:val.capitalize() for (ind, val) in enumerate(["apple", "lemon", "lychee"])})
display(final_df)
# Out:
#                  Apple     Lemon     Lychee
# Hu Moment 1   0.787719  0.241973   0.795756
# Hu Moment 2   3.250386  2.502873   3.897298
# Hu Moment 3   4.989753  3.275508   5.612230
# Hu Moment 4   6.587908  1.842055   8.231718
# Hu Moment 5 -12.828842  4.400839  15.328001
# Hu Moment 6   9.097435  3.494240  10.656874
# Hu Moment 7  12.405654 -6.915659 -15.282765

# %% [markdown]
# ## Top-Down View

# %%
feature_arr = [f"Hu Moment {(i + 1)}" for i in range(7)]
final_df = pd.DataFrame(columns = feature_arr)

fig, axs = plt.subplots(2, 3, figsize=(5,5))

for (ind, img_path) in enumerate(img_path_arr[6:]):
    axs[0, ind].imshow(convert_img_path_to_cv_img(img_path), interpolation = 'nearest')
    axs[0, ind].axis('off')
    
    axs[1, ind].imshow(convert_img_to_canny(img_path), interpolation = 'nearest')
    axs[1, ind].axis('off')
    final_df = final_df.append(gen_hu_moment(convert_img_to_canny(img_path)), ignore_index = True)
plt.show()

final_df = final_df.T
final_df = final_df.rename(columns = {ind:val.capitalize() for (ind, val) in enumerate(["apple", "lemon", "lychee"])})
display(final_df)
# Out:
#                 Apple     Lemon     Lychee
# Hu Moment 1  0.421440 -0.001743   0.796323
# Hu Moment 2  4.050855  2.861774   6.118760
# Hu Moment 3  3.926473  3.723262   5.708901
# Hu Moment 4  2.826168  1.956202   8.288032
# Hu Moment 5  6.636862  5.540194 -15.356084
# Hu Moment 6  4.893900  3.909266 -12.103401
# Hu Moment 7 -6.234053  4.803102 -15.567482

# %% [markdown]
# ## Dimension of Dataset

# %%
df_X.shape
# Out:
# (2940, 9)

# %% [markdown]
# ## Stratified K-Fold Validation

# %%
# kf = KFold(n_splits=4)
# kf.get_n_splits(df_X)

# for train_index, test_index in kf.split(df_X):
#     X_train, X_test = df_X.iloc[train_index], df_X.iloc[test_index]
#     y_train, y_test = df_Y.iloc[train_index], df_Y.iloc[test_index]
# print(len(X_train), len(X_test))

# %% [markdown]
# ## Train Test Split Model

# %%
#Split the dataset
X_train, X_test, y_train, y_test = train_test_split(df_X, df_Y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Train Random Forest Model

# %%
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf_model.predict(X_test)

# %%
clf_report_1 = pd.DataFrame(classification_report(y_test, y_pred, output_dict = True)).T
clf_report_1
# Out:
#               precision    recall  f1-score     support
# Apple          0.871287  0.897959  0.884422   98.000000
# Grape          0.990196  0.980583  0.985366  103.000000
# Lemon          0.881720  0.863158  0.872340   95.000000
# Limes          0.786517  0.909091  0.843373   77.000000
# Lychee         0.880000  0.822430  0.850242  107.000000
# Pear           0.922330  0.879630  0.900474  108.000000
# accuracy       0.891156  0.891156  0.891156    0.891156
# macro avg      0.888675  0.892142  0.889370  588.000000
# weighted avg   0.893662  0.891156  0.891505  588.000000

# %%
confusion_matrix_df = pd.DataFrame(confusion_matrix(y_test, y_pred), index = sorted(df_Y.unique()), columns = sorted(df_Y.unique()))
fig = plt.figure(figsize=(12,12))

sns.heatmap(confusion_matrix_df,annot=True, fmt='g',  cmap="YlGnBu_r")
plt.show()

# %% [markdown]
# ## Feature Importance

# %%
feats = {key:val for (key,val) in zip(df_X.columns, rf_model.feature_importances_)}

# %%
importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Gini-importance'})
importances.sort_values(by='Gini-importance', inplace = True, ascending = False)
importances = importances.iloc[:10]

# %%
importances.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Train Support Vector Machine

# %%
svm_model = svm.SVC(decision_function_shape='ovo')
svm_model.fit(X_train,y_train)
# Out:
# SVC(decision_function_shape='ovo')

# %%
y_pred = svm_model.predict(X_test)

# %%
clf_report_2 = pd.DataFrame(classification_report(y_test, y_pred, output_dict = True)).T
clf_report_2
# Out:
# c:\users\txen2\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\txen2\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\txen2\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# Apple          0.666667  0.306122  0.419580   98.000000
# Grape          0.000000  0.000000  0.000000  103.000000
# Lemon          0.261628  0.473684  0.337079   95.000000
# Limes          0.201954  0.805195  0.322917   77.000000
# Lychee         0.709677  0.411215  0.520710  107.000000
# Pear           0.000000  0.000000  0.000000  108.000000
# accuracy       0.307823  0.307823  0.307823    0.307823
# macro avg      0.306654  0.332703  0.266714  588.000000
# weighted avg   0.308969  0.307823  0.261432  588.000000

# %%
confusion_matrix_df = pd.DataFrame(confusion_matrix(y_test, y_pred), index = sorted(df_Y.unique()), columns = sorted(df_Y.unique()))
fig = plt.figure(figsize=(12,12))

sns.heatmap(confusion_matrix_df,annot=True, fmt='g',  cmap="YlGnBu_r")
plt.show()

# %% [markdown]
# ## Train K Nearest neighbor

# %%
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn_model.predict(X_test)

# %%
# count=0 
# total = df_X.shape[0]
# for i in range(total):
#     check=knn_model.predict([df_X.iloc[i]])
#     if check[0] == df_Y.iloc[i] :
#         count += 1
# print(count)
# print("Accuracy is ", count/total)

# %%
clf_report_3 = pd.DataFrame(classification_report(y_test, y_pred, output_dict = True)).T
clf_report_3
# Out:
#               precision    recall  f1-score     support
# Apple          0.644860  0.704082  0.673171   98.000000
# Grape          0.915094  0.941748  0.928230  103.000000
# Lemon          0.571429  0.547368  0.559140   95.000000
# Limes          0.538462  0.636364  0.583333   77.000000
# Lychee         0.701149  0.570093  0.628866  107.000000
# Pear           0.754717  0.740741  0.747664  108.000000
# accuracy       0.693878  0.693878  0.693878    0.693878
# macro avg      0.687618  0.690066  0.686734  588.000000
# weighted avg   0.696821  0.693878  0.693282  588.000000

# %%
confusion_matrix_df = pd.DataFrame(confusion_matrix(y_test, y_pred), index = sorted(df_Y.unique()), columns = sorted(df_Y.unique()))
fig = plt.figure(figsize=(12,12))

sns.heatmap(confusion_matrix_df,annot=True, fmt='g',  cmap="YlGnBu_r")
plt.show()

# %% [markdown]
# ## Precision, Recall, F1-Score

# %%
def pfr_graph(df, x_label, y_label, title):
    df.plot.bar()
    plt.legend(bbox_to_anchor=(1, 1.05))
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# %%
def get_df_type(model_name, clf_report1, clf_report2, clf_report3, col_name):
    df = pd.DataFrame()
    df[model_name[0]] = clf_report1[col_name][:-3]
    df[model_name[1]] = clf_report2[col_name][:-3]
    df[model_name[2]] = clf_report3[col_name][:-3]
    
    # Replace NA value with 0
    df.fillna(0, inplace=True)
    return df

# %% [markdown]
# ### Precision Graph

# %%
model_name = ["Random Forest", "K-Nearest Neighbor", "Support Vector Machine"]
df = get_df_type(model_name, clf_report_1, clf_report_3, clf_report_2, "precision")
pfr_graph(df, "Types of Fruit", "Score", "Precision Comparison")

# %% [markdown]
# ### Recall Graph

# %%
model_name = ["Random Forest", "K-Nearest Neighbor", "Support Vector Machine"]
df = get_df_type(model_name, clf_report_1, clf_report_3, clf_report_2, "recall")
pfr_graph(df, "Types of Fruit", "Score", "Recall Comparison")

# %% [markdown]
# ### F1-Score Graph

# %%
model_name = ["Random Forest", "K-Nearest Neighbor", "Support Vector Machine"]
df = get_df_type(model_name, clf_report_1, clf_report_3, clf_report_2, "f1-score")
pfr_graph(df, "Types of Fruit", "Score", "F1-Score Comparison")

# %% [markdown]
# ## Precision Recall Curve

# %%
map_fruit_val_dict = {key:val for val, key in enumerate(sorted(df_Y.unique()))}
def map_fruit_val(x):
    arr = [0 for i in range(6)]
    arr[map_fruit_val_dict[x]] = 1
    return arr

# %% [markdown]
# #### Make Y_test into 2d Array

# %%
y_test_arr = [map_fruit_val(key) for key in y_test.to_list()]
y_test_arr = np.array(y_test_arr)

# %% [markdown]
# #### Make Y_Preds into 2d Array

# %%
y_pred = rf_model.predict(X_test)
y_pred_arr = [map_fruit_val(key) for key in y_pred]
y_pred_arr = np.array(y_pred_arr)

# %% [markdown]
# #### Plot Precision Recall Curve

# %%
precision, recall = {}, {}
for ind, val in enumerate(sorted(df_Y.unique())):
    precision[ind], recall[ind], _ = precision_recall_curve(y_test_arr[:, ind], y_pred_arr[:, ind])
    plt.plot(recall[ind], precision[ind], lw=2, label=f"Random Forest - {val}")
    plt.plot(np.linspace(0, 1, 20), np.linspace(1, 0, 20), 'k--')
    
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend(loc = "best")
plt.title("Precision vs. Recall curve")
plt.show()

# %% [markdown]
# ## ROC Curve

# %%
fpr, tpr = {}, {}
for ind, val in enumerate(sorted(df_Y.unique())):
    fpr[ind], tpr[ind], _ = roc_curve(y_test_arr[:, ind],y_pred_arr[:, ind])
    plt.plot(fpr[ind], tpr[ind], lw=2, label=f"Random Forest - {val}")
    plt.plot([0,1], [0, 1], 'k--')
    plt.axis([0, 1, 0, 1])
    
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.legend(loc="best")
plt.title("ROC curve")
plt.show()

# %% [markdown]
# ## Accuracy among the three model

# %%
def acc_graph(model_name_arr ,acc_score_arr, x_label, y_label, title):
    acc_dict = {
        model_name: acc_score for model_name, acc_score in zip(model_name_arr, acc_score_arr)
    }
    df = pd.Series(acc_dict)
    fig, ax = plt.subplots(figsize=(12, 2))
    for ind, val in enumerate(df):
        ax.barh(ind, val, 0.5, label=df.index[ind])
        ax.text(val,ind,f"{val:.3f}%")
    plt.yticks(np.arange(len(df)),df.index)
    plt.legend(bbox_to_anchor=(1, 1.05))
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %%
acc_score_arr = [accuracy_score(y_test, model.predict(X_test)) * 100.0 for model in [rf_model, knn_model, svm_model]]
model_name = ["Random Forest", "K-Nearest Neighbor", "Support Vector Machine"]
acc_graph(model_name, acc_score_arr, "Accuracy Score", "Types of Model", "Accuracy Score Comparison")

# %%
accuracy_report = pd.DataFrame(columns=["Accuracy"])
for (ind, acc_score) in enumerate(acc_score_arr):
    accuracy_report.loc[ind] = acc_score
accuracy_report.index = model_name
accuracy_report
# Out:
#                          Accuracy
# Random Forest           89.115646
# K-Nearest Neighbor      69.387755
# Support Vector Machine  30.782313

# %% [markdown]
# ## Save Model

# %%
model_path = "Models\\\\"
model_arr = [rf_model, svm_model, knn_model]
filename_arr = ["random_forest", "svm","knn"]

# %%
for (model, filename) in zip(model_arr, filename_arr):
    pickle.dump(model, open(f"{model_path}{filename}_model.sav", 'wb'))
